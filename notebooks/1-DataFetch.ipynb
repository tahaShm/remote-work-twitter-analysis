# %% [markdown]
# <h2>Data Fetching</h2>
# <p style="text-indent :2em;"><a href="#Fetching-from-elastic"> 1. Fetching From Elastic.</a></p>
# <p style="text-indent :2em;"><a href="#Cleaning"> 2. Cleaning.</a></p>
#
# <br>

# %%
from elasticsearch import Elasticsearch
from elasticsearch import helpers
from tqdm import tqdm
import csv
import os

# %% [markdown]
# ## Fetching from elastic

# %%
es = Elasticsearch(['http://192.168.1.92:9200'], timeout=30, max_retries=10, retry_on_timeout=True)

# %%
def extractTwitterData(outputFile, fieldNames, ignoredFields, queryBody, index = 'tweets'):
    docCount = 0
    with open(outputFile, 'a') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=fieldNames)
        writer.writeheader()
        for record in tqdm(helpers.scan(es, index=index, query=queryBody)):      
            recordId = record['_id']
            source = record['_source']
            source['_id'] = recordId
            for f in ignoredFields:
                if (source.get(f)):
                    del source[f]

            writer.writerow(source)
            docCount += 1
            
    print("number of rows:", docCount)

# %%
tweetQueryBody = {
  "query": {
    "bool": { 
      "should": [
         {
             "match_phrase": {
                "tweet": "کار از منزل"
             }
         },
         {
             "match_phrase": {
                "tweet": "کار در منزل"
             }
         },
         {
             "match_phrase": {
                "tweet": "کار از خانه"
             }
         },
         {
             "match_phrase": {
                "tweet": "کار در خانه"
             }
         },
         {
            "match_phrase": {
                "tweet": "کار از راه دور"
            }
         },
         {
            "match_phrase": {
                "tweet": "کار ریموت"
            }
         },
         {
            "match_phrase": {
                "tweet": "کار از دور"
            }
         },
         { 
           "query_string": {
                "query": """(دورکاری) 
                        OR (دورکار)
                        OR (teleworking)
                        OR (telecommuting)
                        OR (flexiplace)
                        OR (flexiwork)
                        """, 
                "default_field": "tweet"
            }
        }
      ]
    }
  }
}
tweetOutputFile = '../data/remote_tweets.csv'
tweetFieldNames = ['language', 'conversation_id', 'retweets_count', 'mentions', 'created_at', 
              'likes_count', 'possibly_sensitive', 'in_reply_to_user_id', '_id', 'source', 
              'user_id', 'in_reply_to_status_id', 'tweet', 'replies_count', 'quoted_status_id', 'hashtags', 'cashtags', 'urls']
ignoredTweetFields = ['thumbnail', 'photos', 'videos']

# %% [markdown]
# ### Tweets

# %%
extractTwitterData(tweetOutputFile, tweetFieldNames, ignoredTweetFields, tweetQueryBody)
# Out:
# 43441it [05:52, 123.14it/s]
# number of rows: 43441

# %%
userQueryBody = {}
userOutputFile = '../data/twitter_users.csv'
userFields = ['_id', 'username', 'created_at', 'tweets', 'following', 'followers', 'likes', 'media_count', 'verified']
ignoredUserFields = ['bio', 'profile_image_url', 'background_image', 'pinned_status_ids']

# %% [markdown]
# ### Users

# %%
extractTwitterData(userOutputFile, userFields, ignoredUserFields, userQueryBody, 'users')
# Out:
# 7520298it [34:03, 3680.70it/s]
# number of rows: 7520298

# %% [markdown]
# ## Cleaning

# %%
import pandas as pd

# %%
df_list = []

chunksize = 10 ** 5
with pd.read_csv(tweetOutputFile, chunksize=chunksize) as reader:
    for chunk in tqdm(reader):
        chunk = chunk[chunk.language != 'language']
        chunk.created_at = pd.to_datetime(chunk.created_at)
        
        del chunk['language']
        del chunk['possibly_sensitive']

        chunk.replies_count = pd.to_numeric(chunk.replies_count)
        chunk.retweets_count = pd.to_numeric(chunk.retweets_count)
        chunk.likes_count = pd.to_numeric(chunk.likes_count)
        df_list.append(chunk)
# Out:
# 0it [00:00, ?it/s]/home/taha/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (16) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# 1it [00:00,  1.97it/s]

# %%
result = pd.concat(df_list)
result
# Out:
#            conversation_id  retweets_count                 mentions  \
# 0      1375559420176908296               3                      NaN
# 1      1383828354197979136               2                      NaN
# 2      1383840315031781385               0                      NaN
# 3      1383820625354002439               1             ['15782990']
# 4      1383830770125443083               0                      NaN
# ...                    ...             ...                      ...
# 43436  1434127275587428352               0  ['1273546506012897281']
# 43437  1434127961943326723               0  ['1251428296589488129']
# 43438  1434138057071112194               0                      NaN
# 43439  1434133064750338048               0                      NaN
# 43440  1434121611561558016               0  ['1307304359458418689']
#
#                      created_at  likes_count  in_reply_to_user_id  \
# 0     2021-03-26 21:24:57+00:00          163                  NaN
# 1     2021-04-18 17:02:44+00:00           37                  NaN
# 2     2021-04-18 17:50:16+00:00           11                  NaN
# 3     2021-04-18 17:31:42+00:00            9         1.578299e+07
# 4     2021-04-18 17:12:20+00:00            8                  NaN
# ...                         ...          ...                  ...
# 43436 2021-09-04 12:46:01+00:00            3         1.273547e+18
# 43437 2021-09-04 12:21:54+00:00            2         1.251428e+18
# 43438 2021-09-04 12:55:32+00:00            4                  NaN
# 43439 2021-09-04 12:35:42+00:00           18                  NaN
# 43440 2021-09-04 12:02:55+00:00            1         1.307304e+18
#
#                        _id               source              user_id  \
# 0      1375559420176908296   Twitter for iPhone   812764546012246017
# 1      1383828354197979136  Twitter for Android   985101690536898565
# 2      1383840315031781385      Twitter Web App            310871673
# 3      1383835643239747593      Twitter Web App  1271095835028307969
# 4      1383830770125443083      Twitter Web App   897798038563033088
# ...                    ...                  ...                  ...
# 43436  1434135662396018689  Twitter for Android  1260775960267444225
# 43437  1434129593036939267  Twitter for Android  1214804130096668672
# 43438  1434138057071112194   Twitter for iPhone  1147481863138811905
# 43439  1434133064750338048  Twitter for Android  1106832761216815104
# 43440  1434124815330418691  Twitter for Android  1405163447352975369
#
#        in_reply_to_status_id  \
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3               1.383821e+18
# 4                        NaN
# ...                      ...
# 43436           1.434127e+18
# 43437           1.434128e+18
# 43438                    NaN
# 43439                    NaN
# 43440           1.434122e+18
#
#                                                    tweet  replies_count  \
# 0      اینایی که رفتن سفر، مهمونی و... هیچ پروتکلی هم...              1
# 1      دارم فکر میکنم که چقدر خسته ام با اینکه امروز ...              3
# 2       یک سال و نیمه  از قبل آبان ۹۸ دورکار شدم تا الان              1
# 3      @shahrzaad حتمن میرفتم به شهری که به اقوام یا ...              1
# 4      دورکاری یا کار از خونه خیلی برام فرسایشی شده د...              2
# ...                                                  ...            ...
# 43436  @anar_khanoom آخ لجم میگیره از این همه کثافت د...              0
# 43437  @Nabinabia صرفا جهت اطلاع، ۶ ماهه رزومه فرستاد...              1
# 43438  اگه خواهرم این کار رو استخدام بشه، دورکاری خوا...              0
# 43439                   دورکاری  https://t.co/GYWHxcI9Z4              0
# 43440  @shita_gianz پونیشا انجام میدم سایت هایی هستن ...              1
#
#        quoted_status_id hashtags cashtags urls
# 0                   NaN      NaN      NaN  NaN
# 1                   NaN      NaN      NaN  NaN
# 2          1.383657e+18      NaN      NaN  NaN
# 3                   NaN      NaN      NaN  NaN
# 4                   NaN      NaN      NaN  NaN
# ...                 ...      ...      ...  ...
# 43436               NaN      NaN      NaN  NaN
# 43437               NaN      NaN      NaN  NaN
# 43438               NaN      NaN      NaN  NaN
# 43439               NaN      NaN      NaN  NaN
# 43440               NaN      NaN      NaN  NaN
#
# [43441 rows x 16 columns]

# %%
result.to_csv(tweetOutputFile, index=False)
